# %%
# %load_ext autoreload
# %autoreload 2
import os

from baselines.results_plotter import plot_progress
# %matplotlib inline

log_folder = './exp_logs/left_clip_1024'
print('Plot log from: ', log_folder)
env_list = ['Ant-v2', 'HalfCheetah-v2', 'Hopper-v2', 'Humanoid-v2', 'Walker2d-v2']
log_dirs = [os.path.join(log_folder, env) for env in env_list]
plot_progress(log_dirs)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Plot log from:  ./exp_logs/left_clip_1024
